# %% [markdown]
# <a href="https://colab.research.google.com/github/ChloeZhou1997/BreastCancerCNN/blob/main/Sample_Rebalance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The set of consists of 900 individuals that actually have cancers and there are 14441 samples in which don't have cancers，so we downsampled the dataset to make the dataset balanced

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install pylibjpeg==1.1.1
# !pip install pydicom==2.1.1
# !pip install torchmetrics
# !pip install pytorch_lightning
# !pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.8-cp37-cp37m-linux_x86_64.whl
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pylibjpeg==1.1.1 in /usr/local/lib/python3.7/dist-packages (1.1.1)
# Requirement already satisfied: pylibjpeg-openjpeg in /usr/local/lib/python3.7/dist-packages (from pylibjpeg==1.1.1) (1.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pylibjpeg==1.1.1) (1.21.6)
# Requirement already satisfied: pydicom==2.1.1 in /usr/local/lib/python3.7/dist-packages (2.1.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.7/dist-packages (0.8.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: pyDeprecate==0.3.* in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (0.3.2)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.7/dist-packages (1.6.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (21.3)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.2.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.21.6)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.64.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (2022.3.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (0.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.11.0+cu113)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (2.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch_lightning) (3.0.8)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (57.4.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch_lightning) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.0.12)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (6.0.2)

# %%
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import random

# %%
# Check whether Normal corresponds to 0 

dir = "/content/drive/MyDrive/ForWin/processed/training"

list = os.listdir(dir) # dir is your directory path
print(f"The numer label in training:{list}")

num_of_sample = []
for path in list:
  inner_path = os.path.join(dir,path)
  num_of_sample.append(len(os.listdir(inner_path)))

print(f"The numer list in training:{num_of_sample}")

dir = "/content/drive/MyDrive/ForWin/processed/validation/Normal"
list = os.listdir(dir) # dir is your directory path
print(f"The numer list in training:{len(list)}")
# Out:
# The numer label in training:['Cancer', 'Normal']
# The numer list in training:[900, 14441]
# The numer list in training:1902

# %%
num_of_sample
# Out:
# [900, 14441]

# %%
import random
import copy

original = "/content/drive/MyDrive/ForWin/processed/training"
PATH = "/content/drive/MyDrive/Data/processed/"

folder = os.listdir(original)

for path in folder:
  inner_path = os.path.join(original,path)
  
  file_list = os.listdir(inner_path)

  show_list = random.sample(file_list,900)
  l = copy.deepcopy(show_list)

  for index in range(len(l)):
    file_name = l[index]
    source = os.path.join(inner_path,file_name)

    if index < 800:
      
      destination = os.path.join(PATH,"training",path,file_name)
      os.rename(source, destination)
      
    else:

      destination = os.path.join(PATH,"validation",path,file_name)
      os.rename(source, destination)
# Out:
# 900
# ['DBT-P04647_rmlo.npy', 'DBT-P00988_lcc.npy', 'DBT-P04249_lmlo.npy', 'DBT-P00992_rcc.npy', 'DBT-P00784_rcc.npy', 'DBT-P04450_rcc.npy', 'DBT-P00107_lmlo.npy', 'DBT-P02865_lcc.npy', 'DBT-P04026_rcc1.npy', 'DBT-P03093_rcc.npy', 'DBT-P04450_lmlo.npy', 'DBT-P02891_lmlo.npy', 'DBT-P02161_rmlo.npy', 'DBT-P01796_lmlo.npy', 'DBT-P03231_lcc.npy', 'DBT-P01801_rmlo.npy', 'DBT-P02502_lcc.npy', 'DBT-P01668_lmlo.npy', 'DBT-P02384_lcc.npy', 'DBT-P00491_lcc.npy', 'DBT-P00270_lmlo.npy', 'DBT-P02244_lmlo.npy', 'DBT-P00642_lcc.npy', 'DBT-P00304_rmlo.npy', 'DBT-P00869_rmlo.npy', 'DBT-P05030_rmlo.npy', 'DBT-P00910_rmlo.npy', 'DBT-P04662_lmlo.npy', 'DBT-P02316_lcc.npy', 'DBT-P01822_lcc.npy', 'DBT-P02236_lcc.npy', 'DBT-P02365_rcc.npy', 'DBT-P03973_lmlo.npy', 'DBT-P00754_rcc.npy', 'DBT-P02384_lmlo.npy', 'DBT-P02136_rmlo.npy', 'DBT-P04103_rmlo.npy', 'DBT-P01238_rmlo.npy', 'DBT-P02798_lmlo.npy', 'DBT-P00992_lcc.npy', 'DBT-P00315_lcc.npy', 'DBT-P03973_rmlo.npy', 'DBT-P01491_rmlo.npy', 'DBT-P02161_lmlo.npy', 'DBT-P02365_lcc.npy', 'DBT-P03357_rmlo.npy', 'DBT-P01181_lcc.npy', 'DBT-P01262_rmlo.npy', 'DBT-P01973_rcc.npy', 'DBT-P02600_lcc.npy', 'DBT-P02891_rmlo.npy', 'DBT-P04088_lcc.npy', 'DBT-P04277_rcc.npy', 'DBT-P00411_lmlo.npy', 'DBT-P04116_rcc.npy', 'DBT-P02885_rmlo.npy', 'DBT-P01978_lmlo.npy', 'DBT-P02447_rmlo.npy', 'DBT-P01476_rcc.npy', 'DBT-P01485_lmlo.npy', 'DBT-P04249_rcc.npy', 'DBT-P01673_lcc.npy', 'DBT-P04372_lcc.npy', 'DBT-P05047_rcc.npy', 'DBT-P04291_lcc.npy', 'DBT-P02370_lcc.npy', 'DBT-P01553_lmlo.npy', 'DBT-P01106_rcc.npy', 'DBT-P00661_lcc.npy', 'DBT-P03479_lcc.npy', 'DBT-P01761_lcc.npy', 'DBT-P02176_rmlo.npy', 'DBT-P04096_lcc.npy', 'DBT-P00988_lmlo.npy', 'DBT-P02493_lcc.npy', 'DBT-P03225_rcc.npy', 'DBT-P02176_rcc.npy', 'DBT-P03307_lmlo.npy', 'DBT-P04992_lmlo.npy', 'DBT-P02977_rmlo.npy', 'DBT-P00710_rcc.npy', 'DBT-P00946_rmlo.npy', 'DBT-P01826_lcc.npy', 'DBT-P04096_lmlo.npy', 'DBT-P00183_lmlo.npy', 'DBT-P01999_rcc.npy', 'DBT-P04723_rmlo.npy', 'DBT-P04949_lcc.npy', 'DBT-P02143_rcc.npy', 'DBT-P01461_lmlo.npy', 'DBT-P02600_rcc.npy', 'DBT-P01211_rcc.npy', 'DBT-P00225_lcc.npy', 'DBT-P03292_lcc.npy', 'DBT-P00583_lmlo.npy', 'DBT-P00710_rmlo.npy', 'DBT-P03172_rmlo.npy', 'DBT-P05030_rcc.npy', 'DBT-P03997_rmlo.npy', 'DBT-P04710_rmlo.npy', 'DBT-P00654_lcc.npy', 'DBT-P03434_lcc.npy', 'DBT-P02896_lcc.npy', 'DBT-P04715_lmlo.npy', 'DBT-P02977_lcc.npy', 'DBT-P04514_lmlo.npy', 'DBT-P01157_rcc.npy', 'DBT-P00488_lmlo.npy', 'DBT-P01553_lcc.npy', 'DBT-P00946_lmlo.npy', 'DBT-P02554_rmlo.npy', 'DBT-P01491_rcc.npy', 'DBT-P02171_rmlo.npy', 'DBT-P02525_lmlo.npy', 'DBT-P00499_lmlo.npy', 'DBT-P02798_lcc.npy', 'DBT-P04192_rmlo.npy', 'DBT-P02178_rcc.npy', 'DBT-P03218_lcc.npy', 'DBT-P01319_rcc.npy', 'DBT-P04667_lmlo.npy', 'DBT-P02532_lmlo.npy', 'DBT-P04450_rmlo.npy', 'DBT-P01801_rcc1.npy', 'DBT-P03716_lcc.npy', 'DBT-P00785_lmlo.npy', 'DBT-P04901_rcc.npy', 'DBT-P03568_rmlo.npy', 'DBT-P04662_rcc.npy', 'DBT-P02582_lcc.npy', 'DBT-P01042_rcc.npy', 'DBT-P02896_rcc.npy', 'DBT-P04326_lcc.npy', 'DBT-P05022_rmlo.npy', 'DBT-P01817_lmlo.npy', 'DBT-P00910_lcc.npy', 'DBT-P01319_lcc.npy', 'DBT-P04162_rcc.npy', 'DBT-P03009_rcc.npy', 'DBT-P04526_lcc.npy', 'DBT-P03816_rmlo.npy', 'DBT-P03637_rmlo.npy', 'DBT-P01112_lmlo.npy', 'DBT-P04162_lmlo.npy', 'DBT-P03093_lmlo.npy', 'DBT-P02544_lmlo.npy', 'DBT-P04723_lmlo.npy', 'DBT-P04096_rcc.npy', 'DBT-P02843_lmlo.npy', 'DBT-P00858_lmlo.npy', 'DBT-P04277_lmlo.npy', 'DBT-P02316_rcc.npy', 'DBT-P03915_lcc.npy', 'DBT-P01347_rcc.npy', 'DBT-P04609_rcc.npy', 'DBT-P02967_lmlo.npy', 'DBT-P01027_lmlo.npy', 'DBT-P01411_rcc.npy', 'DBT-P00023_lmlo.npy', 'DBT-P02244_rcc.npy', 'DBT-P04124_lmlo.npy', 'DBT-P03413_rcc.npy', 'DBT-P00986_rmlo.npy', 'DBT-P00538_lmlo.npy', 'DBT-P02236_rmlo.npy', 'DBT-P03073_lcc.npy', 'DBT-P04093_rmlo.npy', 'DBT-P02821_lmlo.npy', 'DBT-P03685_lmlo.npy', 'DBT-P01973_lmlo.npy', 'DBT-P00642_lmlo.npy', 'DBT-P04271_lcc.npy', 'DBT-P02224_rcc.npy', 'DBT-P03685_rcc.npy', 'DBT-P00827_rmlo.npy', 'DBT-P04756_lmlo.npy', 'DBT-P03434_rmlo.npy', 'DBT-P00851_l ...
# 14441
# ['DBT-P04060_rmlo.npy', 'DBT-P03828_rmlo.npy', 'DBT-P02302_rcc.npy', 'DBT-P03871_lmlo.npy', 'DBT-P04535_rcc.npy', 'DBT-P03202_rcc.npy', 'DBT-P01108_lmlo.npy', 'DBT-P00527_rmlo.npy', 'DBT-P04542_rcc.npy', 'DBT-P00141_rmlo.npy', 'DBT-P02646_lcc.npy', 'DBT-P01834_rmlo.npy', 'DBT-P04181_rmlo.npy', 'DBT-P04005_lcc.npy', 'DBT-P04175_rcc.npy', 'DBT-P00722_lcc.npy', 'DBT-P02724_lmlo.npy', 'DBT-P04613_rcc.npy', 'DBT-P00215_rcc.npy', 'DBT-P03931_lcc.npy', 'DBT-P03498_rcc.npy', 'DBT-P03249_rmlo.npy', 'DBT-P00516_rcc.npy', 'DBT-P00418_lcc.npy', 'DBT-P03874_lcc.npy', 'DBT-P00039_lmlo.npy', 'DBT-P03011_lmlo.npy', 'DBT-P01732_lcc.npy', 'DBT-P02121_rcc.npy', 'DBT-P00457_lcc.npy', 'DBT-P03262_lcc.npy', 'DBT-P03664_lmlo.npy', 'DBT-P00638_rmlo.npy', 'DBT-P01069_rcc.npy', 'DBT-P00054_rmlo.npy', 'DBT-P03923_lmlo.npy', 'DBT-P04592_lmlo.npy', 'DBT-P01250_rcc.npy', 'DBT-P01326_lmlo.npy', 'DBT-P01855_lcc.npy', 'DBT-P03260_lmlo.npy', 'DBT-P02029_lmlo.npy', 'DBT-P00923_lmlo.npy', 'DBT-P01504_rmlo.npy', 'DBT-P03584_lmlo.npy', 'DBT-P03499_lcc.npy', 'DBT-P03944_rmlo.npy', 'DBT-P02035_rcc.npy', 'DBT-P01338_rcc.npy', 'DBT-P00342_lcc.npy', 'DBT-P02056_lmlo.npy', 'DBT-P00340_lmlo.npy', 'DBT-P01079_lmlo.npy', 'DBT-P04442_rcc.npy', 'DBT-P04245_rcc.npy', 'DBT-P01884_lcc.npy', 'DBT-P04538_rcc.npy', 'DBT-P01927_lcc.npy', 'DBT-P02660_rcc.npy', 'DBT-P03367_rcc.npy', 'DBT-P00258_lcc.npy', 'DBT-P01383_lcc.npy', 'DBT-P02781_rcc.npy', 'DBT-P01800_lmlo.npy', 'DBT-P03385_lcc.npy', 'DBT-P02074_lcc.npy', 'DBT-P02895_lmlo.npy', 'DBT-P03836_rcc.npy', 'DBT-P01633_rmlo.npy', 'DBT-P00062_lmlo.npy', 'DBT-P03171_rmlo.npy', 'DBT-P01721_rcc.npy', 'DBT-P04971_rcc.npy', 'DBT-P03310_rmlo.npy', 'DBT-P01220_lcc.npy', 'DBT-P04202_rcc.npy', 'DBT-P03792_lmlo.npy', 'DBT-P00964_rmlo.npy', 'DBT-P00421_rmlo.npy', 'DBT-P02146_rcc.npy', 'DBT-P00551_lcc.npy', 'DBT-P01928_lcc.npy', 'DBT-P00169_lmlo.npy', 'DBT-P04965_rcc.npy', 'DBT-P02638_rmlo.npy', 'DBT-P04683_rcc.npy', 'DBT-P04441_rmlo.npy', 'DBT-P01813_rcc.npy', 'DBT-P03757_lmlo.npy', 'DBT-P01166_lmlo.npy', 'DBT-P02426_rmlo.npy', 'DBT-P04943_lcc.npy', 'DBT-P01489_rcc.npy', 'DBT-P04079_rmlo.npy', 'DBT-P03533_rcc.npy', 'DBT-P02175_rmlo.npy', 'DBT-P02008_lmlo.npy', 'DBT-P00065_lmlo.npy', 'DBT-P00145_lmlo.npy', 'DBT-P01871_lcc.npy', 'DBT-P02660_lmlo.npy', 'DBT-P00286_lcc.npy', 'DBT-P02650_rmlo.npy', 'DBT-P03699_lcc.npy', 'DBT-P04443_lmlo.npy', 'DBT-P01467_lcc.npy', 'DBT-P00848_lcc.npy', 'DBT-P03081_lmlo.npy', 'DBT-P00195_lcc.npy', 'DBT-P03579_lcc.npy', 'DBT-P01056_lcc.npy', 'DBT-P02809_rcc.npy', 'DBT-P04973_rcc.npy', 'DBT-P03241_lcc.npy', 'DBT-P04582_lcc.npy', 'DBT-P02114_rcc.npy', 'DBT-P02414_lmlo.npy', 'DBT-P04737_lmlo.npy', 'DBT-P04276_lcc.npy', 'DBT-P00019_lmlo.npy', 'DBT-P00761_rmlo.npy', 'DBT-P00572_lcc.npy', 'DBT-P03352_rmlo.npy', 'DBT-P00749_lcc.npy', 'DBT-P03865_lmlo.npy', 'DBT-P01144_rcc.npy', 'DBT-P03970_rcc.npy', 'DBT-P02116_lcc.npy', 'DBT-P01051_lmlo.npy', 'DBT-P02126_lcc.npy', 'DBT-P02987_lmlo.npy', 'DBT-P02814_lcc.npy', 'DBT-P04739_lmlo.npy', 'DBT-P03004_lcc.npy', 'DBT-P02201_lmlo.npy', 'DBT-P00365_lmlo.npy', 'DBT-P03856_lmlo.npy', 'DBT-P03834_rcc.npy', 'DBT-P04447_lcc.npy', 'DBT-P02076_rcc.npy', 'DBT-P00568_rcc.npy', 'DBT-P02596_rmlo.npy', 'DBT-P02964_lcc.npy', 'DBT-P04551_rcc.npy', 'DBT-P05001_lmlo.npy', 'DBT-P03859_lcc.npy', 'DBT-P04503_rmlo.npy', 'DBT-P02790_lcc.npy', 'DBT-P03620_lmlo.npy', 'DBT-P00164_lmlo.npy', 'DBT-P02858_lcc.npy', 'DBT-P00320_lcc.npy', 'DBT-P03404_lmlo.npy', 'DBT-P04349_lmlo.npy', 'DBT-P02608_lmlo.npy', 'DBT-P04150_lmlo.npy', 'DBT-P02785_lcc.npy', 'DBT-P01660_lcc.npy', 'DBT-P02690_rcc.npy', 'DBT-P02631_rmlo.npy', 'DBT-P03676_rcc.npy', 'DBT-P01281_rmlo.npy', 'DBT-P01902_rcc.npy', 'DBT-P04108_rmlo.npy', 'DBT-P03048_lmlo.npy', 'DBT-P02627_lcc.npy', 'DBT-P02088_lmlo.npy', 'DBT-P03646_rmlo.npy', 'DBT-P01988_rmlo.npy', 'DBT-P01088_lcc.npy', 'DBT-P01327_lmlo.npy', 'DBT-P03885_rcc.npy', 'DBT-P04634_lcc.npy', 'DBT-P00855_lcc.npy', 'DBT-P00282_rcc.npy', 'DBT-P04298_rcc.npy', 'DBT-P03905_lcc.npy', 'DBT-P03779_rmlo.npy', 'D ...
